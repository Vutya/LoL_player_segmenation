# %%
import os
import requests
import pandas as pd
from itertools import product
from statistics import mode, mean
from riotwatcher import LolWatcher, ApiError

# golbal variables
api_key = 'YOUR-API-KEY'
watcher = LolWatcher(api_key)
my_region = 'ru'

# %%
# check league's latest version
latest = watcher.data_dragon.versions_for_region(my_region)['n']['champion']
# Lets get some champions static information
static_champ_list = watcher.data_dragon.champions(latest, False, 'en_US')

# champ static list data to dict for looking up
champ_dict = {}
for key in static_champ_list['data']:
    row = static_champ_list['data'][key]
    champ_dict[row['key']] = row['id']
for row in participants:
    print(str(row['champion']) + ' ' + champ_dict[str(row['champion'])])
    row['championName'] = champ_dict[str(row['champion'])]

# print dataframe
df = pd.DataFrame(participants)
df
# Out:
# 236 Lucian
# 32 Amumu
# 24 Jax
# 350 Yuumi
# 34 Anivia
# 238 Zed
# 92 Riven
# 141 Kayn
# 202 Jhin
# 45 Veigar
#    champion  spell1  spell2    win  kills  deaths  assists  totalDamageDealt  \
# 0       236       4       7  False      0       4        0             27735
# 1        32      11       4  False      8      13       16            176277
# 2        24       4      14  False      7      10        8            223007
# 3       350       3      14  False      4       7       29             38509
# 4        34       4      14  False     29       6        8            405804
# 5       238       4      14   True      6      12       14            102956
# 6        92      12       4   True      5      12        5            216026
# 7       141       4      11   True      9       8        9            341544
# 8       202       4       7   True     16       6       15            292445
# 9        45       4      14   True      4      11       13             67831
#
# ...

# %%
watcher.league.entries(region='ru', queue='RANKED_SOLO_5x5', tier='DIAMOND', division='I', page=2)[0]
# Out:
# {'leagueId': '60a3bfb7-7dab-456c-a9ce-7c163b9008e8',
#  'queueType': 'RANKED_SOLO_5x5',
#  'tier': 'DIAMOND',
#  'rank': 'I',
#  'summonerId': 'lH8g-k2pwfYWB1BSwy3hURW8XLbLPqvjDtOVKW1TMXcnxA',
#  'summonerName': 'uwuowo mne hyevo',
#  'leaguePoints': 20,
#  'wins': 198,
#  'losses': 177,
#  'veteran': False,
#  'inactive': False,
#  'freshBlood': False,
#  'hotStreak': False}

# %%
#leagues = ['IRON', 'BRONZE', 'SILVER',' GOLD', 'PLATINUM', 'DIAMOND']
leagues = ['DIAMOND']
divs = ['I', 'II', 'III', 'IV']

num_players = {}

for tier, division in product(leagues, divs):
    num_players[tier + '_' + division] = 0

for tier, division in product(leagues, divs):
    i = 0
    n = 205
    while n == 205:
        i += 1
        n = len(watcher.league.entries(region='ru', queue='RANKED_SOLO_5x5', tier=tier, 
                                       division=division, page=i))
        num_players[tier + '_' + division] += n
    print(tier, division, ':', num_players[tier + '_' + division])
num_players
# Out:
# DIAMOND I : 298
# DIAMOND II : 453
# DIAMOND III : 983
# DIAMOND IV : 3415
# {'DIAMOND_I': 298, 'DIAMOND_II': 453, 'DIAMOND_III': 983, 'DIAMOND_IV': 3415}

# %%
len(watcher.league.challenger_by_queue(region='ru', queue='RANKED_SOLO_5x5')['entries'])
# Out:
# 50

# %%
len(watcher.league.grandmaster_by_queue(region='ru', queue='RANKED_SOLO_5x5')['entries'])
# Out:
# 100

# %%
len(watcher.league.masters_by_queue(region='ru', queue='RANKED_SOLO_5x5')['entries'])
# Out:
# 27

# %%
num_players_divs = {'IRON I': 7308, 'IRON II': 3618, 'IRON III': 1843, 'IRON IV': 687,
                   'BRONZE I': 23342, 'BRONZE II': 19165, 'BRONZE III': 10768, 'BRONZE IV': 12805,
                   'SILVER I': 17283, 'SILVER II': 24621,'SILVER III': 20891,'SILVER IV': 32604,
                   'GOLD I': 8698, 'GOLD II': 14775, 'GOLD III': 19361, 'GOLD IV': 39939,
                   'PLATINUM I': 4330, 'PLATINUM II': 3561, 'PLATINUM III': 5376, 'PLATINUM IV': 17784,
                   'DIAMOND I': 296, 'DIAMOND II': 453, 'DIAMOND III': 985, 'DIAMOND IV': 3410}
num_players_leagues = {'IRON': 13456, 'BRONZE': 66080, 'SILVER': 95399, 'GOLD': 82773, 'PLATINUM': 31051, 
                      'DIAMOND': 5144, 'MASTER': 23, 'GRANDMASTER': 99, 'CHALLENGER': 50}
sum(num_players_leagues.values())
# Out:
# 294075

# %%
len(watcher.league.entries(region='ru', queue='RANKED_SOLO_5x5', tier="GOLD", division='I', page=1))
# Out:
# 205

# %%
# MASTER

# dict for all players
sum_d = {'Account ID': [], 'Summoner Name': [], 'Rank': [], 'Role': [], 'Lane': [], 
    'win': [], 'kills': [], 'deaths': [], 
    'assists': [], 'doubleKills': [], 'tripleKills': [], 'quadraKills': [], 'pentaKills': [], 
    'unrealKills': [], 'goldEarned': [], 'goldSpent': [], 'inhibitorKills': [], 'turretKills': [], 
    'totalMinionsKilled': [], 'neutralMinionsKilled': [], 'neutralMinionsKilledTeamJungle': [], 'neutralMinionsKilledEnemyJungle': [],
    'killingSprees': [], 'largestCriticalStrike': [], 'largestKillingSpree': [], 'largestMultiKill': [], 
    'longestTimeSpentLiving': [], 'visionScore': [], 'wardsPlaced': [], 'wardsKilled': [], 'visionWardsBoughtInGame': [], 
    'sightWardsBoughtInGame': [], 'magicDamageDealt': [], 'magicDamageDealtToChampions': [], 'magicalDamageTaken': [], 
    'physicalDamageDealt': [], 'physicalDamageDealtToChampions': [], 'physicalDamageTaken': [], 'trueDamageDealt': [], 
    'trueDamageDealtToChampions': [], 'trueDamageTaken': [], 'totalDamageDealt': [], 'totalDamageDealtToChampions': [], 
    'totalDamageTaken': [], 'damageDealtToTurrets': [], 'damageDealtToObjectives': [],  'totalHeal': [], 'totalUnitsHealed': [], 
    'totalTimeCrowdControlDealt': [], 'damageSelfMitigated': [], 'timeCCingOthers': [], 'champLevel': []}

for entry in watcher.league.masters_by_queue(region='ru', queue='RANKED_SOLO_5x5')['entries']:
    # dict for a single player
    d = {'Account ID': [], 'Summoner Name': [], 'Rank': [], 'Game ID': [], 'Role': [], 'Lane': [], 'Champion': [], 
    'Spell 1 ID': [], 'Spell 2 ID': [], 'win': [], 'kills': [], 'deaths': [], 
    'assists': [], 'doubleKills': [], 'tripleKills': [], 'quadraKills': [], 'pentaKills': [], 
    'unrealKills': [], 'goldEarned': [], 'goldSpent': [], 'inhibitorKills': [], 'turretKills': [], 
    'totalMinionsKilled': [], 'neutralMinionsKilled': [], 'neutralMinionsKilledTeamJungle': [], 'neutralMinionsKilledEnemyJungle': [],
    'killingSprees': [], 'largestCriticalStrike': [], 'largestKillingSpree': [], 'largestMultiKill': [], 
    'longestTimeSpentLiving': [], 'visionScore': [], 'wardsPlaced': [], 'wardsKilled': [], 'visionWardsBoughtInGame': [], 
    'sightWardsBoughtInGame': [], 'magicDamageDealt': [], 'magicDamageDealtToChampions': [], 'magicalDamageTaken': [], 
    'physicalDamageDealt': [], 'physicalDamageDealtToChampions': [], 'physicalDamageTaken': [], 'trueDamageDealt': [], 
    'trueDamageDealtToChampions': [], 'trueDamageTaken': [], 'totalDamageDealt': [], 'totalDamageDealtToChampions': [], 
    'totalDamageTaken': [], 'damageDealtToTurrets': [], 'damageDealtToObjectives': [],  'totalHeal': [], 'totalUnitsHealed': [], 
    'totalTimeCrowdControlDealt': [], 'damageSelfMitigated': [], 'timeCCingOthers': [], 'champLevel': []}
    
    # look for accountId by summonerId for a player from specific league
    summoner_info = watcher.summoner.by_id('ru', entry['summonerId'])
    acc_id = summoner_info['accountId']
    
    # if data is loaded then continue
    if (summoner_info['name'] + '.csv') in os.listdir('./Data/MASTER'):
        continue
    
    # get 100 matches played in ranked solo queue in 2020 season
    my_matches = watcher.match.matchlist_by_account('ru', encrypted_account_id=acc_id, queue=420, season=13)
    
    # loop over all matches
    for match in my_matches['matches']:
        
        # saving Summoner Name, Account ID, Game ID, Role, Lane and Champion + adding rank
        d['Summoner Name'].append(summoner_info['name'])
        d['Account ID'].append(acc_id)
        d['Role'].append(match['role'])
        d['Lane'].append(match['lane'])
        d['Champion'].append(match['champion'])
        d['Game ID'].append(match['gameId'])
        d['Rank'].append('MASTER')
        
        # download statistics by match Id
        match_stat = watcher.match.by_id(region=match['platformId'].lower(), match_id=match['gameId'])
 
        # save PartcipantId for current player
        for player in match_stat['participantIdentities']:
            if acc_id == player['player']['accountId'] or entry['summonerId'] == player['player']['summonerId']:
                participant_id = player['participantId']
                #d['Participant ID'].append(participant_id)
        
        # from participants we extract match_stat 
        for player in match_stat['participants']:
            if participant_id == player['participantId']:
                full_info = player

        # saving spell1Id, spell2Id + all necessary statistics
        d['Spell 1 ID'].append(full_info['spell1Id'])
        d['Spell 2 ID'].append(full_info['spell2Id'])
        keys = ['win', 'kills', 'deaths', 'assists', 'doubleKills', 'tripleKills', 'quadraKills', 'pentaKills', 'unrealKills', 
               'goldEarned', 'goldSpent', 'inhibitorKills', 'turretKills', 'totalMinionsKilled', 'neutralMinionsKilled', 
               'neutralMinionsKilledTeamJungle', 'neutralMinionsKilledEnemyJungle', 'killingSprees', 'largestCriticalStrike',
               'largestKillingSpree', 'largestMultiKill', 'longestTimeSpentLiving', 'visionScore', 'wardsPlaced', 'wardsKilled', 
               'visionWardsBoughtInGame', 'sightWardsBoughtInGame', 'magicDamageDealt', 'magicDamageDealtToChampions', 'magicalDamageTaken', 
               'physicalDamageDealt', 'physicalDamageDealtToChampions', 'physicalDamageTaken', 'trueDamageDealt', 'trueDamageDealtToChampions',
               'trueDamageTaken', 'totalDamageDealt', 'totalDamageDealtToChampions', 'totalDamageTaken', 'damageDealtToTurrets', 
               'damageDealtToObjectives', 'totalHeal', 'totalUnitsHealed', 'totalTimeCrowdControlDealt', 'damageSelfMitigated',
               'timeCCingOthers', 'champLevel']
        for key in keys:
            d[key].append(full_info['stats'][key])
    
    # saving to csv
    pd.DataFrame(data=d).to_csv('./Data/MASTER/' + summoner_info['name'] + '.csv', index=False, sep='\t')
    
    # averaging data
    sum_d['Account ID'].append(acc_id)
    sum_d['Summoner Name'].append(summoner_info['name'])
    sum_d['Rank'].append('MASTER')
    sum_d['Role'].append(mode(d['Role']))
    sum_d['Lane'].append(mode(d['Lane']))
    sum_d['win'].append(sum(d['win']))
    mean_keys = ['kills', 'deaths', 'assists', 'goldEarned', 'goldSpent', 'magicDamageDealt', 
                 'magicDamageDealtToChampions', 'magicalDamageTaken', 'physicalDamageDealt', 
                 'physicalDamageDealtToChampions', 'physicalDamageTaken', 'trueDamageDealt', 
                 'trueDamageDealtToChampions', 'trueDamageTaken', 'totalDamageDealt', 
                 'totalDamageDealtToChampions', 'totalDamageTaken', 'longestTimeSpentLiving', 
                 'damageDealtToTurrets', 'damageDealtToObjectives', 'totalHeal', 'totalUnitsHealed', 
                 'visionScore', 'wardsPlaced', 'wardsKilled', 'visionWardsBoughtInGame', 
                 'sightWardsBoughtInGame', 'totalTimeCrowdControlDealt', 'damageSelfMitigated',
                 'timeCCingOthers', 'totalMinionsKilled', 'neutralMinionsKilled', 'largestCriticalStrike',
                 'neutralMinionsKilledTeamJungle', 'neutralMinionsKilledEnemyJungle', 'champLevel',
                 'doubleKills', 'tripleKills', 'quadraKills', 'pentaKills', 'unrealKills', 
                 'inhibitorKills', 'turretKills', 'killingSprees', 'largestKillingSpree', 
                 'largestMultiKill']
    for mk in mean_keys:
        sum_d[mk].append(mean(d[mk]))

# saving averaged data to a file
pd.DataFrame(data=sum_d).to_csv('./Data/Master.csv', index=False, sep='\t')

# %%
# GRANDMASTER

# dict for all players
sum_d = {'Account ID': [], 'Summoner Name': [], 'Rank': [], 'Role': [], 'Lane': [], 
    'win': [], 'kills': [], 'deaths': [], 
    'assists': [], 'doubleKills': [], 'tripleKills': [], 'quadraKills': [], 'pentaKills': [], 
    'unrealKills': [], 'goldEarned': [], 'goldSpent': [], 'inhibitorKills': [], 'turretKills': [], 
    'totalMinionsKilled': [], 'neutralMinionsKilled': [], 'neutralMinionsKilledTeamJungle': [], 'neutralMinionsKilledEnemyJungle': [],
    'killingSprees': [], 'largestCriticalStrike': [], 'largestKillingSpree': [], 'largestMultiKill': [], 
    'longestTimeSpentLiving': [], 'visionScore': [], 'wardsPlaced': [], 'wardsKilled': [], 'visionWardsBoughtInGame': [], 
    'sightWardsBoughtInGame': [], 'magicDamageDealt': [], 'magicDamageDealtToChampions': [], 'magicalDamageTaken': [], 
    'physicalDamageDealt': [], 'physicalDamageDealtToChampions': [], 'physicalDamageTaken': [], 'trueDamageDealt': [], 
    'trueDamageDealtToChampions': [], 'trueDamageTaken': [], 'totalDamageDealt': [], 'totalDamageDealtToChampions': [], 
    'totalDamageTaken': [], 'damageDealtToTurrets': [], 'damageDealtToObjectives': [],  'totalHeal': [], 'totalUnitsHealed': [], 
    'totalTimeCrowdControlDealt': [], 'damageSelfMitigated': [], 'timeCCingOthers': [], 'champLevel': []}

for entry in watcher.league.grandmaster_by_queue(region='ru', queue='RANKED_SOLO_5x5')['entries']:
    # dict for a single player
    d = {'Account ID': [], 'Summoner Name': [], 'Rank': [], 'Game ID': [], 'Role': [], 'Lane': [], 'Champion': [], 
    'Spell 1 ID': [], 'Spell 2 ID': [], 'win': [], 'kills': [], 'deaths': [], 
    'assists': [], 'doubleKills': [], 'tripleKills': [], 'quadraKills': [], 'pentaKills': [], 
    'unrealKills': [], 'goldEarned': [], 'goldSpent': [], 'inhibitorKills': [], 'turretKills': [], 
    'totalMinionsKilled': [], 'neutralMinionsKilled': [], 'neutralMinionsKilledTeamJungle': [], 'neutralMinionsKilledEnemyJungle': [],
    'killingSprees': [], 'largestCriticalStrike': [], 'largestKillingSpree': [], 'largestMultiKill': [], 
    'longestTimeSpentLiving': [], 'visionScore': [], 'wardsPlaced': [], 'wardsKilled': [], 'visionWardsBoughtInGame': [], 
    'sightWardsBoughtInGame': [], 'magicDamageDealt': [], 'magicDamageDealtToChampions': [], 'magicalDamageTaken': [], 
    'physicalDamageDealt': [], 'physicalDamageDealtToChampions': [], 'physicalDamageTaken': [], 'trueDamageDealt': [], 
    'trueDamageDealtToChampions': [], 'trueDamageTaken': [], 'totalDamageDealt': [], 'totalDamageDealtToChampions': [], 
    'totalDamageTaken': [], 'damageDealtToTurrets': [], 'damageDealtToObjectives': [],  'totalHeal': [], 'totalUnitsHealed': [], 
    'totalTimeCrowdControlDealt': [], 'damageSelfMitigated': [], 'timeCCingOthers': [], 'champLevel': []}
    
    # look for accountId by summonerId for a player from specific league
    summoner_info = watcher.summoner.by_id('ru', entry['summonerId'])
    acc_id = summoner_info['accountId']
    
    # if data is loaded then continue
    if (summoner_info['name'] + '.csv') in os.listdir('./Data/GRANDMASTER'):
        continue
    
    # get 100 matches played in ranked solo queue in 2020 season
    my_matches = watcher.match.matchlist_by_account('ru', encrypted_account_id=acc_id, queue=420, season=13)
    
    # loop over all matches
    for match in my_matches['matches']:
        
        # saving Summoner Name, Account ID, Game ID, Role, Lane and Champion + adding rank
        d['Summoner Name'].append(summoner_info['name'])
        d['Account ID'].append(acc_id)
        d['Role'].append(match['role'])
        d['Lane'].append(match['lane'])
        d['Champion'].append(match['champion'])
        d['Game ID'].append(match['gameId'])
        d['Rank'].append('GRANDMASTER')
        
        # download statistics by match Id
        match_stat = watcher.match.by_id(region=match['platformId'].lower(), match_id=match['gameId'])
 
        # save PartcipantId for current player
        for player in match_stat['participantIdentities']:
            if acc_id == player['player']['accountId'] or entry['summonerId'] == player['player']['summonerId']:
                participant_id = player['participantId']
                #d['Participant ID'].append(participant_id)
        
        # from participants we extract match_stat
        for player in match_stat['participants']:
            if participant_id == player['participantId']:
                full_info = player

        # saving spell1Id, spell2Id + all necessary statistics
        d['Spell 1 ID'].append(full_info['spell1Id'])
        d['Spell 2 ID'].append(full_info['spell2Id'])
        keys = ['win', 'kills', 'deaths', 'assists', 'doubleKills', 'tripleKills', 'quadraKills', 'pentaKills', 'unrealKills', 
               'goldEarned', 'goldSpent', 'inhibitorKills', 'turretKills', 'totalMinionsKilled', 'neutralMinionsKilled', 
               'neutralMinionsKilledTeamJungle', 'neutralMinionsKilledEnemyJungle', 'killingSprees', 'largestCriticalStrike',
               'largestKillingSpree', 'largestMultiKill', 'longestTimeSpentLiving', 'visionScore', 'wardsPlaced', 'wardsKilled', 
               'visionWardsBoughtInGame', 'sightWardsBoughtInGame', 'magicDamageDealt', 'magicDamageDealtToChampions', 'magicalDamageTaken', 
               'physicalDamageDealt', 'physicalDamageDealtToChampions', 'physicalDamageTaken', 'trueDamageDealt', 'trueDamageDealtToChampions',
               'trueDamageTaken', 'totalDamageDealt', 'totalDamageDealtToChampions', 'totalDamageTaken', 'damageDealtToTurrets', 
               'damageDealtToObjectives', 'totalHeal', 'totalUnitsHealed', 'totalTimeCrowdControlDealt', 'damageSelfMitigated',
               'timeCCingOthers', 'champLevel']
        for key in keys:
            d[key].append(full_info['stats'][key])
    
    # saving to csv
    pd.DataFrame(data=d).to_csv('./Data/GRANDMASTER/' + summoner_info['name'] + '.csv', index=False, sep='\t')
    
    # averaging data
    sum_d['Account ID'].append(acc_id)
    sum_d['Summoner Name'].append(summoner_info['name'])
    sum_d['Rank'].append('GRANDMASTER')
    sum_d['Role'].append(mode(d['Role']))
    sum_d['Lane'].append(mode(d['Lane']))
    sum_d['win'].append(sum(d['win']))
    mean_keys = ['kills', 'deaths', 'assists', 'goldEarned', 'goldSpent', 'magicDamageDealt', 
                 'magicDamageDealtToChampions', 'magicalDamageTaken', 'physicalDamageDealt', 
                 'physicalDamageDealtToChampions', 'physicalDamageTaken', 'trueDamageDealt', 
                 'trueDamageDealtToChampions', 'trueDamageTaken', 'totalDamageDealt', 
                 'totalDamageDealtToChampions', 'totalDamageTaken', 'longestTimeSpentLiving', 
                 'damageDealtToTurrets', 'damageDealtToObjectives', 'totalHeal', 'totalUnitsHealed', 
                 'visionScore', 'wardsPlaced', 'wardsKilled', 'visionWardsBoughtInGame', 
                 'sightWardsBoughtInGame', 'totalTimeCrowdControlDealt', 'damageSelfMitigated',
                 'timeCCingOthers', 'totalMinionsKilled', 'neutralMinionsKilled', 'largestCriticalStrike',
                 'neutralMinionsKilledTeamJungle', 'neutralMinionsKilledEnemyJungle', 'champLevel',
                 'doubleKills', 'tripleKills', 'quadraKills', 'pentaKills', 'unrealKills', 
                 'inhibitorKills', 'turretKills', 'killingSprees', 'largestKillingSpree', 
                 'largestMultiKill']
    for mk in mean_keys:
        sum_d[mk].append(mean(d[mk]))

# saving averaged data to a file
pd.DataFrame(data=sum_d).to_csv('./Data/Grandmaster.csv', index=False, sep='\t')

# %%
# CHALLENGER

# dict for all players
sum_d = {'Account ID': [], 'Summoner Name': [], 'Rank': [], 'Role': [], 'Lane': [], 
         'win': [], 'kills': [], 'deaths': [], 'assists': [], 'doubleKills': [], 'tripleKills': [], 
    'quadraKills': [], 'pentaKills': [], 'unrealKills': [], 'goldEarned': [], 'goldSpent': [], 'inhibitorKills': [], 'turretKills': [], 
    'totalMinionsKilled': [], 'neutralMinionsKilled': [], 'neutralMinionsKilledTeamJungle': [], 'neutralMinionsKilledEnemyJungle': [],
    'killingSprees': [], 'largestCriticalStrike': [], 'largestKillingSpree': [], 'largestMultiKill': [], 
    'longestTimeSpentLiving': [], 'visionScore': [], 'wardsPlaced': [], 'wardsKilled': [], 'visionWardsBoughtInGame': [], 
    'sightWardsBoughtInGame': [], 'magicDamageDealt': [], 'magicDamageDealtToChampions': [], 'magicalDamageTaken': [], 
    'physicalDamageDealt': [], 'physicalDamageDealtToChampions': [], 'physicalDamageTaken': [], 'trueDamageDealt': [], 
    'trueDamageDealtToChampions': [], 'trueDamageTaken': [], 'totalDamageDealt': [], 'totalDamageDealtToChampions': [], 
    'totalDamageTaken': [], 'damageDealtToTurrets': [], 'damageDealtToObjectives': [],  'totalHeal': [], 'totalUnitsHealed': [], 
    'totalTimeCrowdControlDealt': [], 'damageSelfMitigated': [], 'timeCCingOthers': [], 'champLevel': []}

for entry in watcher.league.challenger_by_queue(region='ru', queue='RANKED_SOLO_5x5')['entries']:
    # dict for a single player
    d = {'Account ID': [], 'Summoner Name': [], 'Rank': [], 'Game ID': [], 'Role': [], 'Lane': [], 'Champion': [], 
    'Spell 1 ID': [], 'Spell 2 ID': [], 'win': [], 'kills': [], 'deaths': [], 
    'assists': [], 'doubleKills': [], 'tripleKills': [], 'quadraKills': [], 'pentaKills': [], 
    'unrealKills': [], 'goldEarned': [], 'goldSpent': [], 'inhibitorKills': [], 'turretKills': [], 
    'totalMinionsKilled': [], 'neutralMinionsKilled': [], 'neutralMinionsKilledTeamJungle': [], 'neutralMinionsKilledEnemyJungle': [],
    'killingSprees': [], 'largestCriticalStrike': [], 'largestKillingSpree': [], 'largestMultiKill': [], 
    'longestTimeSpentLiving': [], 'visionScore': [], 'wardsPlaced': [], 'wardsKilled': [], 'visionWardsBoughtInGame': [], 
    'sightWardsBoughtInGame': [], 'magicDamageDealt': [], 'magicDamageDealtToChampions': [], 'magicalDamageTaken': [], 
    'physicalDamageDealt': [], 'physicalDamageDealtToChampions': [], 'physicalDamageTaken': [], 'trueDamageDealt': [], 
    'trueDamageDealtToChampions': [], 'trueDamageTaken': [], 'totalDamageDealt': [], 'totalDamageDealtToChampions': [], 
    'totalDamageTaken': [], 'damageDealtToTurrets': [], 'damageDealtToObjectives': [],  'totalHeal': [], 'totalUnitsHealed': [], 
    'totalTimeCrowdControlDealt': [], 'damageSelfMitigated': [], 'timeCCingOthers': [], 'champLevel': []}
    
    # look for accountId by summonerId for a player from specific league
    summoner_info = watcher.summoner.by_id('ru', entry['summonerId'])
    acc_id = summoner_info['accountId']
    
    # if data is loaded then continue
    if (summoner_info['name'] + '.csv') in os.listdir('./Data/CHALLENGER'):
        continue
    
    # get 100 matches played in ranked solo queue in 2020 season
    my_matches = watcher.match.matchlist_by_account('ru', encrypted_account_id=acc_id, queue=420, season=13)
    
    # loop over all matches
    for match in my_matches['matches']:
        
        # saving Summoner Name, Account ID, Game ID, Role, Lane and Champion + adding rank
        d['Summoner Name'].append(summoner_info['name'])
        d['Account ID'].append(acc_id)
        d['Role'].append(match['role'])
        d['Lane'].append(match['lane'])
        d['Champion'].append(match['champion'])
        d['Game ID'].append(match['gameId'])
        d['Rank'].append('CHALLENGER')
        
        # download statistics by match Id
        match_stat = watcher.match.by_id(region=match['platformId'].lower(), match_id=match['gameId'])
 
        # save PartcipantId for current player
        for player in match_stat['participantIdentities']:
            if acc_id == player['player']['accountId'] or entry['summonerId'] == player['player']['summonerId']:
                participant_id = player['participantId']
                #d['Participant ID'].append(participant_id)
        
        # from participants we extract match_stat
        for player in match_stat['participants']:
            if participant_id == player['participantId']:
                full_info = player

        # saving spell1Id, spell2Id + all necessary statistics
        d['Spell 1 ID'].append(full_info['spell1Id'])
        d['Spell 2 ID'].append(full_info['spell2Id'])
        keys = ['win', 'kills', 'deaths', 'assists', 'doubleKills', 'tripleKills', 'quadraKills', 'pentaKills', 'unrealKills', 
               'goldEarned', 'goldSpent', 'inhibitorKills', 'turretKills', 'totalMinionsKilled', 'neutralMinionsKilled', 
               'neutralMinionsKilledTeamJungle', 'neutralMinionsKilledEnemyJungle', 'killingSprees', 'largestCriticalStrike',
               'largestKillingSpree', 'largestMultiKill', 'longestTimeSpentLiving', 'visionScore', 'wardsPlaced', 'wardsKilled', 
               'visionWardsBoughtInGame', 'sightWardsBoughtInGame', 'magicDamageDealt', 'magicDamageDealtToChampions', 'magicalDamageTaken', 
               'physicalDamageDealt', 'physicalDamageDealtToChampions', 'physicalDamageTaken', 'trueDamageDealt', 'trueDamageDealtToChampions',
               'trueDamageTaken', 'totalDamageDealt', 'totalDamageDealtToChampions', 'totalDamageTaken', 'damageDealtToTurrets', 
               'damageDealtToObjectives', 'totalHeal', 'totalUnitsHealed', 'totalTimeCrowdControlDealt', 'damageSelfMitigated',
               'timeCCingOthers', 'champLevel']
        for key in keys:
            d[key].append(full_info['stats'][key])

    # saving to csv
    pd.DataFrame(data=d).to_csv('./Data/CHALLENGER/' + summoner_info['name'] + '.csv', index=False, sep='\t')
    
    # averaging data
    sum_d['Account ID'].append(acc_id)
    sum_d['Summoner Name'].append(summoner_info['name'])
    sum_d['Rank'].append('CHALLENGER')
    sum_d['Role'].append(mode(d['Role']))
    sum_d['Lane'].append(mode(d['Lane']))
    sum_d['win'].append(sum(d['win']))
    mean_keys = ['kills', 'deaths', 'assists', 'goldEarned', 'goldSpent', 'magicDamageDealt', 
                 'magicDamageDealtToChampions', 'magicalDamageTaken', 'physicalDamageDealt', 
                 'physicalDamageDealtToChampions', 'physicalDamageTaken', 'trueDamageDealt', 
                 'trueDamageDealtToChampions', 'trueDamageTaken', 'totalDamageDealt', 
                 'totalDamageDealtToChampions', 'totalDamageTaken', 'longestTimeSpentLiving', 
                 'damageDealtToTurrets', 'damageDealtToObjectives', 'totalHeal', 'totalUnitsHealed', 
                 'visionScore', 'wardsPlaced', 'wardsKilled', 'visionWardsBoughtInGame', 
                 'sightWardsBoughtInGame', 'totalTimeCrowdControlDealt', 'damageSelfMitigated',
                 'timeCCingOthers', 'totalMinionsKilled', 'neutralMinionsKilled', 'largestCriticalStrike',
                 'neutralMinionsKilledTeamJungle', 'neutralMinionsKilledEnemyJungle', 'champLevel',
                 'doubleKills', 'tripleKills', 'quadraKills', 'pentaKills', 'unrealKills', 
                 'inhibitorKills', 'turretKills', 'killingSprees', 'largestKillingSpree', 
                 'largestMultiKill']
    for mk in mean_keys:
        sum_d[mk].append(mean(d[mk]))

# saving averaged data to a file
pd.DataFrame(data=sum_d).to_csv('./Data/Challenger.csv', index=False, sep='\t')

# %%
# number of players to check in each league
num_leagues = {'IRON I': 224, 'IRON II': 258, 'IRON III': 270, 'IRON IV': 306,
               'BRONZE I': 260, 'BRONZE II': 241, 'BRONZE III': 258, 'BRONZE IV': 279,
               'SILVER I': 186, 'SILVER II': 199,'SILVER III': 216,'SILVER IV': 224,
               'GOLD I': 160, 'GOLD II': 157, 'GOLD III': 168, 'GOLD IV': 185,
               'PLATINUM I': 144, 'PLATINUM II': 133, 'PLATINUM III': 151, 'PLATINUM IV': 157,
               'DIAMOND I': 173, 'DIAMOND II': 131, 'DIAMOND III': 126, 'DIAMOND IV': 155
              }

# saving players with matches < 100 in order to skip them later (convenice due to rank stabilization)
less100 = []

# loop runs again if getting an error from server
while True:
    try:
        for k, v in num_leagues.items():

            print(k)

            # league and division
            tier, division = k.split()

             # dict for all players
            sum_d = {'Account ID': [], 'Summoner Name': [], 'Rank': [], 'Role': [], 'Lane': [], 
                         'win': [], 'kills': [], 'deaths': [], 'assists': [], 'doubleKills': [], 'tripleKills': [], 
                    'quadraKills': [], 'pentaKills': [], 'unrealKills': [], 'goldEarned': [], 'goldSpent': [], 'inhibitorKills': [], 'turretKills': [], 
                    'totalMinionsKilled': [], 'neutralMinionsKilled': [], 'neutralMinionsKilledTeamJungle': [], 'neutralMinionsKilledEnemyJungle': [],
                    'killingSprees': [], 'largestCriticalStrike': [], 'largestKillingSpree': [], 'largestMultiKill': [], 
                    'longestTimeSpentLiving': [], 'visionScore': [], 'wardsPlaced': [], 'wardsKilled': [], 'visionWardsBoughtInGame': [], 
                    'sightWardsBoughtInGame': [], 'magicDamageDealt': [], 'magicDamageDealtToChampions': [], 'magicalDamageTaken': [], 
                    'physicalDamageDealt': [], 'physicalDamageDealtToChampions': [], 'physicalDamageTaken': [], 'trueDamageDealt': [], 
                    'trueDamageDealtToChampions': [], 'trueDamageTaken': [], 'totalDamageDealt': [], 'totalDamageDealtToChampions': [], 
                    'totalDamageTaken': [], 'damageDealtToTurrets': [], 'damageDealtToObjectives': [],  'totalHeal': [], 'totalUnitsHealed': [], 
                    'totalTimeCrowdControlDealt': [], 'damageSelfMitigated': [], 'timeCCingOthers': [], 'champLevel': []}

            all_matches = []
            for i in range(1, 2 + v // 205):
                all_matches += watcher.league.entries(region='ru', queue='RANKED_SOLO_5x5', tier=tier, division=division, page=i)

            for entry in all_matches[:v]:
                # dict for a single player
                d = {'Account ID': [], 'Summoner Name': [], 'Rank': [], 'Game ID': [], 'Role': [], 'Lane': [], 'Champion': [], 
                'Spell 1 ID': [], 'Spell 2 ID': [], 'win': [], 'kills': [], 'deaths': [], 
                'assists': [], 'doubleKills': [], 'tripleKills': [], 'quadraKills': [], 'pentaKills': [], 
                'unrealKills': [], 'goldEarned': [], 'goldSpent': [], 'inhibitorKills': [], 'turretKills': [], 
                'totalMinionsKilled': [], 'neutralMinionsKilled': [], 'neutralMinionsKilledTeamJungle': [], 'neutralMinionsKilledEnemyJungle': [],
                'killingSprees': [], 'largestCriticalStrike': [], 'largestKillingSpree': [], 'largestMultiKill': [], 
                'longestTimeSpentLiving': [], 'visionScore': [], 'wardsPlaced': [], 'wardsKilled': [], 'visionWardsBoughtInGame': [], 
                'sightWardsBoughtInGame': [], 'magicDamageDealt': [], 'magicDamageDealtToChampions': [], 'magicalDamageTaken': [], 
                'physicalDamageDealt': [], 'physicalDamageDealtToChampions': [], 'physicalDamageTaken': [], 'trueDamageDealt': [], 
                'trueDamageDealtToChampions': [], 'trueDamageTaken': [], 'totalDamageDealt': [], 'totalDamageDealtToChampions': [], 
                'totalDamageTaken': [], 'damageDealtToTurrets': [], 'damageDealtToObjectives': [],  'totalHeal': [], 'totalUnitsHealed': [], 
                'totalTimeCrowdControlDealt': [], 'damageSelfMitigated': [], 'timeCCingOthers': [], 'champLevel': []}

                # look for accountId by summonerId for a player from specific league
                summoner_info = watcher.summoner.by_id('ru', entry['summonerId'])
                acc_id = summoner_info['accountId']

                # if data is loaded then continue
                if (summoner_info['name'] + '.csv') in os.listdir('./Data/' + tier + '/' + division):
                    continue

                # get 100 matches played in ranked solo queue in 2020 season
                if summoner_info['name'] in less100:
                    continue

                # get 100 matches played in ranked solo queue in 2020 season
                my_matches = watcher.match.matchlist_by_account('ru', encrypted_account_id=acc_id, queue=420, season=13)

                # skip if number of matches < 100
                if len(my_matches['matches']) < 100:
                    less100.append(summoner_info['name'])
                    continue

                # loop over all matches
                for match in my_matches['matches']:

                    # saving Summoner Name, Account ID, Game ID, Role, Lane and Champion + adding rank
                    d['Summoner Name'].append(summoner_info['name'])
                    d['Account ID'].append(acc_id)
                    d['Role'].append(match['role'])
                    d['Lane'].append(match['lane'])
                    d['Champion'].append(match['champion'])
                    d['Game ID'].append(match['gameId'])
                    d['Rank'].append(k)

                    # download statistics by match Id
                    match_stat = watcher.match.by_id(region=match['platformId'].lower(), match_id=match['gameId'])

                    # save PartcipantId for current player
                    for player in match_stat['participantIdentities']:
                        if acc_id == player['player']['accountId'] or entry['summonerId'] == player['player']['summonerId']:
                            participant_id = player['participantId']
                            #d['Participant ID'].append(participant_id)

                    # from participants we extract match_stat
                    for player in match_stat['participants']:
                        if participant_id == player['participantId']:
                            full_info = player

                    # saving spell1Id, spell2Id + all necessary statistics
                    d['Spell 1 ID'].append(full_info['spell1Id'])
                    d['Spell 2 ID'].append(full_info['spell2Id'])
                    keys = ['win', 'kills', 'deaths', 'assists', 'doubleKills', 'tripleKills', 'quadraKills', 'pentaKills', 'unrealKills', 
                           'goldEarned', 'goldSpent', 'inhibitorKills', 'turretKills', 'totalMinionsKilled', 'neutralMinionsKilled', 
                           'neutralMinionsKilledTeamJungle', 'neutralMinionsKilledEnemyJungle', 'killingSprees', 'largestCriticalStrike',
                           'largestKillingSpree', 'largestMultiKill', 'longestTimeSpentLiving', 'visionScore', 'wardsPlaced', 'wardsKilled', 
                           'visionWardsBoughtInGame', 'sightWardsBoughtInGame', 'magicDamageDealt', 'magicDamageDealtToChampions', 'magicalDamageTaken', 
                           'physicalDamageDealt', 'physicalDamageDealtToChampions', 'physicalDamageTaken', 'trueDamageDealt', 'trueDamageDealtToChampions',
                           'trueDamageTaken', 'totalDamageDealt', 'totalDamageDealtToChampions', 'totalDamageTaken', 'damageDealtToTurrets', 
                           'damageDealtToObjectives', 'totalHeal', 'totalUnitsHealed', 'totalTimeCrowdControlDealt', 'damageSelfMitigated',
                           'timeCCingOthers', 'champLevel']
                    for key in keys:
                        d[key].append(full_info['stats'][key])

                # saving to csv
                pd.DataFrame(data=d).to_csv('./Data/' + tier + '/' + division + '/'+ summoner_info['name'] + '.csv', index=False, sep='\t')     
    except requests.HTTPError:
        continue
    break
# Out:
# SILVER II
# SILVER II
# SILVER II
# SILVER II
# SILVER II
# SILVER II
# SILVER II
# SILVER II
# SILVER II
